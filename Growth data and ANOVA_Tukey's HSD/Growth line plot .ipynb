# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/mnt/c/Users/nawendt/Desktop/GL data/test4.csv')
pal = ('#1A2384', '#8B0A07', '#048041', '#3447FF', '#FF0000', '#00C982')
plt.ylim(-1,75)
sb.lineplot(
    data=data, x="Day", y="Growth", hue="Combined", err_style="bars", ci=95, palette=pal, legend=None)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Growth'>

# %%
data=pd.read_csv('/mnt/c/Users/nawendt/Desktop/GL data/test5_no105.csv')
plt.ylim(-1,75)
sb.lineplot(
    data=data, x="Day", y="Growth", hue="Combined", err_style="bars", ci=95, palette=dict(CSbrevicompactum="#1A2384", CSexpansum="#8B0A07", CSoxalicum="#048041", GLbrevicompactum="#3447FF", GLexpansum="#FF0000", GLoxalicum="#00C982"), legend=None)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='Growth'>
